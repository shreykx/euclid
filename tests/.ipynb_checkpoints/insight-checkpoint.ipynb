# %% [markdown]
# # `insight.ipynb`

# %% [markdown]
# #### positional encoding and detecting symbols
# a brief diagram showing how this is gonna work
#
# ![image.png](attachment:515948fa-e18b-4354-8494-dd6b63a44090.png)

# %% [markdown]
# #### node graph that tells positions (step: 2)
# type of node graph we'd expect as the output from our positional encoder model
#
# ![image.png](attachment:e2553a64-fe76-487f-bf1e-ecf15275dcca.png)

# %% [markdown]
# ![image.png](attachment:04f37028-04c7-4b12-ac42-586ffd265b2f.png)

# %% [markdown]
# Training dtype: files of `.inkml` format.
# Data source:
# Reference: [InkML previewer](https://www.cs.rit.edu/~rlaz/inkml_viewer/index.xhtml)
