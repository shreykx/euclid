# %% [markdown]
# # `model.ipynb`

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import sqlite3

class Model():
    def __init__(self):
        pass
